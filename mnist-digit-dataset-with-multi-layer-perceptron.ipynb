# %% [markdown]
# # mnist Digit dataset With Multi Layer Perceptron.
#
# **Here Iam using Tensorflow**
#
# Import the necessary library files as below

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten,Input
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# **Loding the data**

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# **Normalizing the data to the scale of 1 to 0 . Each pixel has the pixel ranges from 0 to 255**

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # Model Architecture Explanation
#
#     •We are using 1 input layer, 4 hidden layers, and 1 output layer.
#
# 	•The input image has a shape of 28×28 pixels, which is flattened into 784 features using the Flatten() layer.
#
# 	•The first hidden layer has 392 neurons — roughly half of the flattened input (784).
#
#    **Each subsequent hidden layer reduces the number of neurons by half:**
#
# 	•2nd layer: 192 neurons
#
# 	•3rd layer: 98 neurons
#
# 	•This progressive halving strategy helps the model learn abstract patterns efficiently, reducing complexity as it goes deeper.
#
# 	•The output layer has 10 neurons, representing the digits 0 through 9, with a softmax activation to produce probability scores.
#
# 	•We use:
#
# 	    •ReLU (Rectified Linear Unit) as the activation function for all hidden layers to introduce non-linearity.
#
# 	    •Softmax in the output layer to get class probabilities for multi-class classification.

# %%
model=Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(392,activation='relu'),
    Dense(192,activation='relu'),
    Dense(98,activation='relu'),
    Dense(10,activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **As you decrese the batch size the accuracy of the model will increase more as it adjust the weights and bias after each 32 items are seen by the model, but learning speed will decrease. Here we use 32 as batch size with is good for this**

# %%
model.fit(
    x_train,y_train,
    epochs=15,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8850 - loss: 0.3768 - val_accuracy: 0.9727 - val_loss: 0.0892
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9712 - loss: 0.0938 - val_accuracy: 0.9767 - val_loss: 0.0817
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9802 - loss: 0.0617 - val_accuracy: 0.9755 - val_loss: 0.0824
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9845 - loss: 0.0471 - val_accuracy: 0.9775 - val_loss: 0.0841
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9874 - loss: 0.0405 - val_accuracy: 0.9795 - val_loss: 0.0730
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9904 - loss: 0.0291 - val_accuracy: 0.9788 - val_loss: 0.0822
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9930 - loss: 0.0217 - val_accuracy: 0.9815 - val_loss: 0.0739
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9924 - loss: 0.0219 - val_accuracy: 0.9780 - val_loss: 0.0974
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9939 - loss: 0.0207 - val_accuracy: 0.9832 - val_loss: 0.0790
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9950 - loss: 0.0157 - val_accuracy: 0.9803 - val_loss: 0.0830
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9945 - loss: 0.0160 - val_accuracy: 0.9822 - val_loss: 0.0877
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9949 - loss: 0.0179 - val_accuracy: 0.9805 - val_loss: 0.0945
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9820 - val_loss: 0.0961
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9953 - loss: 0.0149 - val_accuracy: 0.9792 - val_loss: 0.1097
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9960 - loss: 0.0136 - val_accuracy: 0.9788 - val_loss: 0.1092

# %%
print(model.summary())
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 392)            │       307,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 192)            │        75,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 98)             │        18,914 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 10)             │           990 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,209,242 (4.61 MB)
#  Trainable params: 403,080 (1.54 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 806,162 (3.08 MB)
# None

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.9770
